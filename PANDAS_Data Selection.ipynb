# %%
import pandas as pd

# %%
pandas=pd.read_csv(r"D:\STUDY\DATA SCIENCE\BIG DATA PRACTICE\DSL data sets\8. Netflix Dataset.csv")

# %%
pandas1=pd.read_csv(r"D:\STUDY\DATA SCIENCE\BIG DATA PRACTICE\DSL data sets\2. Cars Data.csv")

# %%
pandas1
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
pandas
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# Selection by object Index and Selection by integer Index.
#s.loc / s.iloc
pandas1.nunique()
# Out:
# Make            38
# Model          425
# Type             6
# Origin           3
# DriveTrain       3
# MSRP           410
# Invoice        425
# EngineSize      43
# Cylinders        7
# Horsepower     110
# MPG_City        28
# MPG_Highway     33
# Weight         348
# Wheelbase       40
# Length          67
# dtype: int64

# %%
pandas.Country.iloc[0]
# Out:
# 'Brazil'

# %%
pandas.Country.iloc[0:5]
# Out:
# 0           Brazil
# 1           Mexico
# 2        Singapore
# 3    United States
# 4    United States
# Name: Country, dtype: object

# %%
pandas.Country[0]
# Out:
# 'Brazil'

# %%
pandas.Country.index
# Out:
# RangeIndex(start=0, stop=7789, step=1)

# %%
pandas.Country.index[0:5]
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
#Series Indexing - s[0] , s[‘index’] , s.index , s[0:5] , s[‘index1’:’index2’] , s[0:-1] , s[-3,-1] , s[::-1] 
#s.loc / s.iloc - s.loc[‘index’] , s.loc[‘index1’:’index2’] , s.iloc[0] , s.iloc[0:3]

# %%
#Boolean Series Indexing 
#Show a new series with boolean condition satisfied.
#s[s>=20] 
pandas1.head(1)
# Out:
#     Make Model Type Origin DriveTrain      MSRP   Invoice  EngineSize  \
# 0  Acura   MDX  SUV   Asia        All  $36,945   $33,337          3.5
#
#    Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0        6.0       265.0      17.0         23.0  4451.0      106.0   189.0

# %%
pandas1.Cylinders.head(1)
# Out:
# 0    6.0
# Name: Cylinders, dtype: float64

# %%
# Selecting single column from the DF.
# df[‘Col_name’] , df.Col_name
pandas1["Origin"]
# Out:
# 0        Asia
# 1        Asia
# 2        Asia
# 3        Asia
# 4        Asia
#         ...
# 427    Europe
# 428    Europe
# 429    Europe
# 430    Europe
# 431    Europe
# Name: Origin, Length: 432, dtype: object

# %%
pandas1.Origin
# Out:
# 0        Asia
# 1        Asia
# 2        Asia
# 3        Asia
# 4        Asia
#         ...
# 427    Europe
# 428    Europe
# 429    Europe
# 430    Europe
# 431    Europe
# Name: Origin, Length: 432, dtype: object

# %%
#Selecting multiple Columns from the DF.
#df[[‘Col1’, ‘Col2’ , ‘Col3’ ]]
pandas1[["Make", "Model","Type"]]
# Out:
#       Make                    Model   Type
# 0    Acura                      MDX    SUV
# 1    Acura           RSX Type S 2dr  Sedan
# 2    Acura                  TSX 4dr  Sedan
# 3    Acura                   TL 4dr  Sedan
# 4    Acura               3.5 RL 4dr  Sedan
# ..     ...                      ...    ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan
# 428  Volvo  C70 HPT convertible 2dr  Sedan
# 429  Volvo               S80 T6 4dr  Sedan
# 430  Volvo                      V40  Wagon
# 431  Volvo                     XC70  Wagon
#
# [432 rows x 3 columns]

# %%
#Selecting multiple Columns from the DF
# df.iloc[ : , [1, 3, 5 ]] 
pandas.iloc[:,[0,5]]
# Out:
#      Show_Id                                            Country
# 0         s1                                             Brazil
# 1         s2                                             Mexico
# 2         s3                                          Singapore
# 3         s4                                      United States
# 4         s5                                      United States
# ...      ...                                                ...
# 7784   s7783  Sweden, Czech Republic, United Kingdom, Denmar...
# 7785   s7784                                              India
# 7786   s7785                                                NaN
# 7787   s7786                                          Australia
# 7788   s7787              United Kingdom, Canada, United States
#
# [7789 rows x 2 columns]

# %%
# Selecting columns with object slicing.
# df.loc[ : , ‘Col1’ : ‘Col2’] 
pandas1.loc[:, 'Make':'Model']
# Out:
#       Make                    Model
# 0    Acura                      MDX
# 1    Acura           RSX Type S 2dr
# 2    Acura                  TSX 4dr
# 3    Acura                   TL 4dr
# 4    Acura               3.5 RL 4dr
# ..     ...                      ...
# 427  Volvo  C70 LPT convertible 2dr
# 428  Volvo  C70 HPT convertible 2dr
# 429  Volvo               S80 T6 4dr
# 430  Volvo                      V40
# 431  Volvo                     XC70
#
# [432 rows x 2 columns]

# %%
#Selecting columns with integer slicing
# df.iloc[ : , 1:4 ]
pandas.iloc[:,0:4]
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director
# 0                   NaN
# 1     Jorge Michel Grau
# 2          Gilbert Chan
# 3           Shane Acker
# 4        Robert Luketic
# ...                 ...
# 7784        Josef Fares
# ...

# %%
# Selecting single row from the DF
#df.loc[‘Row_index’] 
pandas.loc[2]
# Out:
# Show_Id                                                        s3
# Category                                                    Movie
# Title                                                       23:59
# Director                                             Gilbert Chan
# Cast            Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# Country                                                 Singapore
# Release_Date                                    December 20, 2018
# Rating                                                          R
# Duration                                                   78 min
# Type                          Horror Movies, International Movies
# Description     When an army recruit is found dead, his fellow...
# Name: 2, dtype: object

# %%
#Selecting multiple rows from the DF.
#df.loc[[‘index1’ , ‘index2’ , ‘index3’ ]] 
pandas1.loc[[1,2,5]]
# Out:
#     Make                    Model   Type Origin DriveTrain      MSRP  \
# 1  Acura           RSX Type S 2dr  Sedan   Asia      Front  $23,820
# 2  Acura                  TSX 4dr  Sedan   Asia      Front  $26,990
# 5  Acura  3.5 RL w/Navigation 4dr  Sedan   Asia      Front  $46,100
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 1  $21,761          2.0        4.0       200.0      24.0         31.0  2778.0
# 2  $24,647          2.4        4.0       200.0      22.0         29.0  3230.0
# 5  $41,100          3.5        6.0       225.0      18.0         24.0  3893.0
#
#    Wheelbase  Length
# 1      101.0   172.0
# 2      105.0   183.0
# 5      115.0   197.0

# %%
#Selecting rows with object slicing.
# df[‘index1’ : ‘index2’ ] 
pandas[2:4]
# Out:
#   Show_Id Category  Title      Director  \
# 2      s3    Movie  23:59  Gilbert Chan
# 3      s4    Movie      9   Shane Acker
#
#                                                 Cast        Country  \
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...

# %%
# Selecting rows & columns with slicing using loc( )
#df.loc[‘index1’ : ‘index2’ , ‘Col1’ : ‘Col2’] #
pandas.loc[2:3, "Country":"Director"]
# Out:
# Empty DataFrame
# Columns: []
# Index: [2, 3]

# %%
# Selecting rows & columns with slicing using iloc ( )
# df.iloc[ 1:3 , 1:3] 
pandas.head(5)
#pandas.iloc[1:3,1:3]
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
pandas.iloc[1:3,1:3]
# Out:
#   Category  Title
# 1    Movie  07:19
# 2    Movie  23:59

# %%
# Selecting one row and one column by label.
# df.loc[‘row_label’ , ‘col_label’] 
pandas.loc[2,"Country"]
# Out:
# 'Singapore'

# %%
# Selecting one row and one column by index
# df.iloc[‘row_index’ , ‘col_index’] 
pandas.iloc[3,3]
# Out:
# 'Shane Acker'

# %%
#Selecting multiple rows & multiple columns
# df.iloc[[2,4,6],[2,4,6]] 
pandas.iloc[[2,4,6],[2,4,6]]
# Out:
#    Title                                               Cast       Release_Date
# 2  23:59  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  December 20, 2018
# 4     21  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...    January 1, 2020
# 6    122  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...       June 1, 2020

# %%
#Showing the elements of the DF which are greater than 3
# df>3 , df[df>3] 
pandas>3
pandas1[pandas>3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20048\1829026124.py in <module>
#       1 #Showing the elements of the DF which are greater than 3
#       2 # df>3 , df[df>3]
# ----> 3 pandas>3
#       4 pandas1[pandas>3]
#       5
#
# ~\a\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\a\anaconda3\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ~\a\anaconda3\lib\site-packages\pandas\core\frame.py in _cmp_method(self, other, op)
# ...

# %%
#20. data.loc["2012-01-06", 'Stn Press (kPa)'][2:4]
#21. Selecting columns by data-type - df.select_dtypes(include = 'number' / ‘int’ / ‘float’ / ‘object’)
df.select_dtypes(include = [‘object’ , ‘number’ , ‘category’ , ‘datetime’] ) 
df.select_dtypes(exclude = 'number' / ‘int’ / ‘float’ / ‘object’
